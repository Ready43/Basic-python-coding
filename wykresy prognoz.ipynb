# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_excel('prognozy_modeli.xlsx')

df.set_index("Data", inplace=True)

# df.index = df.index + pd.DateOffset(hours=1)

df = pd.DataFrame(df)

# %%
# y = df["Ceny niestand"]
# print(y)

# y_lstm = df["LSTM"]
# print(y_lstm)

# y_sarima = df["SARIMAX"]
# print(y_sarima)

# %%
# plt.figure(figsize=(12,6), dpi=1000)
# plt.plot(y, label ='Ceny energii', linestyle = 'dashed', linewidth =3)
# plt.plot(y_lstm, label ='Prognoza LSTM')
# plt.plot(y_sarima, label ='Prognoza SARIMAX')
# plt.legend(loc='lower left')

# plt.xlim(pd.Timestamp('2023-05-25'), df.index[-1])
# plt.ylim(0)

# plt.xlabel('Czas [dzień, miesiąc, godzina]')
# plt.ylabel('Cena energii [Zł/kWh]')

# plt.xticks(rotation=0)


# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M')) # :%S'

# plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=12, tz=df.index.tz)) 


# # [1::2] means start from the second element in the list and get every other element
# for tick in plt.gca().xaxis.get_major_ticks()[1::2]:
#     tick.set_pad(15)

# # first_tick = df.index[0].replace(minute=0, second=0)
# # plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=4, tz=first_tick.tzinfo)) 

# #plt.gca().xaxis.set_label_coords(-0.5, 0)

# plt.savefig('Wykresy prognoz.png')

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Wczytaj dane z pliku Excel

# # Wybierz kolumny z danymi do wykresu
# columns_to_plot = ['Ceny niestand', 'LSTM', 'SARIMAX']

# # Stwórz wykres
# plt.figure(figsize=(12, 6))
# for column in columns_to_plot:
#     plt.plot(df.index, df[column], label=column)

# # Dodaj etykiety i legendę
# plt.xlabel('Data')
# plt.ylabel('Ceny')
# plt.title('Porównanie danych')

# plt.legend()

# # Wyświetl lub zapisz wykres
# plt.tight_layout()
# plt.show()

# %% [markdown]
# wykres 3d

# %%
# # Przekształć kolumnę 'Data' na format daty
# data['Data'] = pd.to_datetime(data['Data'], format='%d.%m.%Y %H:%M')

# # Wybierz tylko daty, które są trzecimi środami miesiąca
# wednesdays = data[data['Data'].dt.weekday == 2]  # 2 oznacza środę w Pandas (poniedziałek = 0, wtorek = 1, środa = 2, ...)
# third_wednesdays = wednesdays[wednesdays['Data'].dt.day <= 21]  # Dla uproszczenia zakładamy, że trzecia środa jest przed 22 dniem miesiąca

# # Tworzenie macierzy danych
# x = third_wednesdays['Data'].dt.hour.values
# y = np.arange(1, len(third_wednesdays) + 1)
# z = third_wednesdays['Ceny energii'].values.reshape(len(x), -1)

# # Tworzenie wykresu 3D w postaci powierzchniowej
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# x, y = np.meshgrid(x, y)  # Tworzenie siatki 2D dla osi X i Y

# # Rysowanie wykresu powierzchniowego
# surf = ax.plot_surface(x, y, z, cmap='viridis')

# # Ustalanie etykiet osi
# ax.set_xlabel('Godzina')
# ax.set_ylabel('Wyniki liczbowe')
# ax.set_zlabel('Cena energii')

# # Dostosowanie podziałek na osi Y
# ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# # Wyświetlenie kolorowej tabeli z legendą
# fig.colorbar(surf, ax=ax, label='Cena energii')

# # Rotacja wykresu, aby poprawić widoczność
# ax.view_init(elev=20, azim=-45)

# # Wyświetlenie wykresu
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# from matplotlib.ticker import MaxNLocator

# # Wczytaj dane z pliku Excel z kropkami jako separatorem dziesiętnym
# data = pd.read_excel('ceny_stand_kropki.xlsx', decimal=',')

# # Przekształć kolumnę 'Data' na format daty
# data['Data'] = pd.to_datetime(data['Data'], format='%d.%m.%Y %H:%M')

# # Wybierz tylko daty, które są środami
# wednesdays = data[data['Data'].dt.weekday == 2]  # 2 oznacza środę w Pandas (poniedziałek = 0, wtorek = 1, środa = 2, ...)

# # Oblicz różnicę w dniach między datą a datą bazową
# date_base = wednesdays['Data'].min()
# y = (wednesdays['Data'] - date_base).dt.days.values
# x = wednesdays['Data'].dt.hour.values
# z = wednesdays['Ceny energii'].values

# # Tworzenie wykresu 3D w postaci powierzchniowej
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # Rysowanie wykresu 3D w postaci powierzchniowej
# surf = ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.2)

# # Ustalanie etykiet osi
# ax.set_xlabel('Godzina', fontsize=12)
# ax.set_ylabel('Dni od daty bazowej', fontsize=12)
# ax.set_zlabel('Cena energii', fontsize=12)

# # Dostosowanie podziałek na osi Y
# ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# # Wyświetlenie kolorowej tabeli z legendą
# fig.colorbar(surf, ax=ax, label='Cena energii')

# # Zmiana kątów widoku
# ax.view_init(elev=20, azim=-45)

# # Wyświetlenie wykresu
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# from matplotlib.ticker import MaxNLocator

# # Wczytaj dane z pliku Excel z kropkami jako separatorem dziesiętnym
# data = pd.read_excel('ceny_stand_kropki.xlsx', decimal=',')

# # Przekształć kolumnę 'Data' na format daty
# data['Data'] = pd.to_datetime(data['Data'], format='%d.%m.%Y %H:%M')

# # Wybierz tylko daty, które są środami
# wednesdays = data[data['Data'].dt.weekday == 2]  # 2 oznacza środę w Pandas (poniedziałek = 0, wtorek = 1, środa = 2, ...)

# # Oblicz różnicę w dniach między datą a datą bazową
# date_base = wednesdays['Data'].min()
# y = (wednesdays['Data'] - date_base).dt.days.values
# x = wednesdays['Data'].dt.hour.values
# z = wednesdays['Ceny energii'].values

# %%
# # Tworzenie wykresu 3D w postaci powierzchniowej
# fig = plt.figure()                          # figsize=(10,6), dpi = 1000
# ax = fig.add_subplot(111, projection='3d')

# # Rysowanie wykresu 3D w postaci powierzchniowej z inną mapą kolorów
# surf = ax.plot_trisurf(x, y, z, cmap='coolwarm', linewidth=0.2, antialiased=True)

# # Ustalanie etykiet osi
# ax.set_xlabel('Godzina', fontsize=12)
# ax.set_ylabel('Dni od daty bazowej', fontsize=12)
# ax.set_zlabel('Cena energii', fontsize=12)

# # Dostosowanie podziałek na osi Y
# ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# # Wyświetlenie kolorowej tabeli z legendą
# # fig.colorbar(surf, ax=ax, label='Cena energii')

# # Zmiana kątów widoku
# ax.view_init(elev=30, azim=-35)

# # Wyświetlenie wykresu
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# # Wczytaj dane z pliku Excel z kropkami jako separatorem dziesiętnym
# data = pd.read_excel('ceny_stand.xlsx', decimal=',')

# # Przekształć kolumnę 'Data' na format daty
# data['Data'] = pd.to_datetime(data['Data'], format='%d.%m.%Y %H:%M')

# # Wybierz tylko daty, które są środami
# wednesdays = data[data['Data'].dt.weekday == 2]

# # Odfiltruj co 7 dni
# wednesdays = wednesdays[wednesdays.index % 7 == 0]

# # Przekształć datę na dni i godziny
# wednesdays['Godzina'] = wednesdays['Data'].dt.hour

# # Oblicz różnicę w dniach między datą a datą bazową
# date_base = wednesdays['Data'].min()
# x = (wednesdays['Data'] - date_base).apply(lambda x: x.days).values
# y = wednesdays['Godzina'].values
# z = wednesdays['Ceny energii'].values

# # Tworzenie wykresu 3D w postaci powierzchniowej
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # Rysowanie wykresu 3D w postaci powierzchniowej
# surf = ax.plot_trisurf(x, y, z, cmap='coolwarm', linewidth=0.2, antialiased=True)

# # Ustalanie etykiet osi
# ax.set_xlabel('Dni od daty bazowej', fontsize=12)
# ax.set_ylabel('Godzina', fontsize=12)
# ax.set_zlabel('Cena energii', fontsize=12)

# # Zmiana kątów widoku
# ax.view_init(elev=20, azim=-45)

# # Wyświetlenie wykresu
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator

# %%
df = pd.read_excel('ceny_stand.xlsx', decimal=',')

df_3 = df[df['Dzien'] == 4.00]
df_3 = df_3.drop(df_3.columns[[2]], axis=1)
df_3 = pd.DataFrame(df_3)
df_3['Data'] = pd.to_datetime(df_3['Data'], format='%d.%m.%Y %H:%M')
df_3['Godzina'] = df_3['Data'].dt.hour
df_3['Dzien'] = df_3['Data'].dt.day

iteracja = []
zmienna = 0
for i in range(len(df_3)):
    if df_3['Dzien'].iloc[i] == df_3['Dzien'].iloc[i-1] :
        
        iteracja.append (zmienna)
    else:
        zmienna += 1
        iteracja.append (zmienna)

df_3['Ieracja'] = iteracja

# %%
#df_3
# Out:
#                     Data  Ceny energii  Godzina  Dzien
# 72   2023-01-04 00:00:00        594.07        0      4
# 73   2023-01-04 01:00:00        561.30        1      4
# 74   2023-01-04 02:00:00        599.98        2      4
# 75   2023-01-04 03:00:00        560.63        3      4
# 76   2023-01-04 04:00:00        568.36        4      4
# ...                  ...           ...      ...    ...
# 3619 2023-05-31 19:00:00        682.06       19     31
# 3620 2023-05-31 20:00:00        685.75       20     31
# 3621 2023-05-31 21:00:00        682.23       21     31
# 3622 2023-05-31 22:00:00        655.77       22     31
# 3623 2023-05-31 23:00:00        528.65       23     31
#
# [528 rows x 4 columns]

# %%
# Tworzenie wykresu 3D w postaci powierzchniowej
fig = plt.figure()                          # figsize=(10,6), dpi = 1000
ax = fig.add_subplot(111, projection='3d')

# Rysowanie wykresu 3D w postaci powierzchniowej z inną mapą kolorów
surf = ax.plot_trisurf(df_3['Ieracja'], df_3['Godzina'], df_3['Ceny energii'], cmap='rainbow', linewidth=0.2, antialiased=True)

# Ustalanie etykiet osi
ax.set_xlabel('Numer iteracyjny środy', fontsize=12)
ax.set_ylabel('Godzina', fontsize=12)
ax.set_zlabel('Cena energii', fontsize=12)

#ax.invert_yaxis()
ax.invert_xaxis()

# Dostosowanie podziałek na osi Y
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# Wyświetlenie kolorowej tabeli z legendą
#fig.colorbar(surf, ax=ax, label='Cena energii')

# Zmiana kątów widoku
ax.view_init(elev=30, azim=35)

#ax.grid(True)

# Wyświetlenie wykresu
plt.savefig('Wykresy 3D+45.png')
